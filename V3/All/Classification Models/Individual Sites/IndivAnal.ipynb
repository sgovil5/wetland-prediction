# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Acc, Sens, Spec, AUC
CastleBay = [0.6149, 0.6154, 0.6143, 0.65]
MasonHT = [0.8497, 0.8454, 0.8571, 0.91]
MasonLT = [0.8553, 0.8438, 0.8750, 0.90]
Maysville = [0.65, 0.3333, 0.8113, 0.72]
RiverRoad = [0.6444, 0.6526, 0.625, 0.72]
StJames = [0.5926, 0.4750, 0.9286, 0.87]
SurfCity = [0.7261, 0.8958, 0.4950, 0.79]
Topsail = [0.6556, 0.9362, 0.3488, 0.67]

# %%
names = ["Castle Bay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]
acc = [CastleBay[0], MasonHT[0], MasonLT[0], Maysville[0], RiverRoad[0], StJames[0], SurfCity[0], Topsail[0]]
sens = [CastleBay[1], MasonHT[1], MasonLT[1], Maysville[1], RiverRoad[1], StJames[1], SurfCity[1], Topsail[1]]
spec = [CastleBay[2], MasonHT[2], MasonLT[2], Maysville[2], RiverRoad[2], StJames[2], SurfCity[2], Topsail[2]]
auc = [CastleBay[3], MasonHT[3], MasonLT[3], Maysville[3], RiverRoad[3], StJames[3], SurfCity[3], Topsail[3]]
df = pd.DataFrame(list(zip(names, acc, sens, spec, auc)), columns=["Site", "Accuracy", "Sensitivity", "Specificity", "AUC"])

# %%
fig, ax = plt.subplots(figsize=(10,5))
df.drop('AUC', axis=1).plot.bar(x="Site", rot=0, ax=ax)
plt.yticks(np.arange(0, 1.1, 0.1))
ax.legend(loc="upper left")

# %%
fig, ax = plt.subplots(figsize=(10,5))
df.plot.bar(x="Site", y="AUC", rot=0, ax=ax)
ax.set_ylim([0,1])
plt.yticks(np.arange(0, 1.1, 0.1))
# Out:
# ([<matplotlib.axis.YTick at 0x1e29c744dc0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
