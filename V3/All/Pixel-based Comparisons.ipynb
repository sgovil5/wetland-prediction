# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
sns.set(rc={"figure.dpi":500, 'savefig.dpi':1000}) #defining dpi setting
plt.rcParams['figure.dpi'] = 500 #display 70 dpi in Jupyter Notebook, may consider100 dpi

# %%
#Gradient boosting models

GBM = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]
GBM_accuracy = [0.7329, 0.8366, 0.7961, 0.7250, 0.8370, 0.8796, 0.8153, 0.7889]
GBM_specificity = [0.7000, 0.7679, 0.7500, 0.8113, 0.7500, 0.7500, 0.7705, 0.7209]
GBM_sensitivity = [0.7582, 0.8763, 0.8229, 0.5556, 0.8737, 0.9250, 0.8438, 0.8511]

#Gradient boosting models with the all comparison

GBM_v2 = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All"]
GBM_accuracy_v2 = [0.7329, 0.8366, 0.7961, 0.7250, 0.8370, 0.8796, 0.8153, 0.7889, 0.8301]
GBM_specificity_v2 = [0.7000, 0.7679, 0.7500, 0.8113, 0.7500, 0.7500, 0.7705, 0.7209, 0.7469]
GBM_sensitivity_v2 = [0.7582, 0.8763, 0.8229, 0.5556, 0.8737, 0.9250, 0.8438, 0.8511, 0.8839]

# %%
#Light Gradient boosting models

LGBM = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]
LGBM_accuracy = [0.7081, 0.8366, 0.8421, 0.7625, 0.8815, 0.8796, 0.7580, 0.7778]
LGBM_specificity = [0.7000, 0.7500, 0.8036, 0.8302, 0.7250, 0.7857, 0.6885, 0.7209]
LGBM_sensitivity = [0.7143, 0.8866, 0.8646, 0.6296, 0.9474, 0.9125, 0.8021, 0.8298] 

#Light Gradient Boosting Models with the all comparison

LGBM_v2 = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All"]
LGBM_accuracy_v2 = [0.7081, 0.8366, 0.8421, 0.7625, 0.8815, 0.8796, 0.7580, 0.7778, 0.8127]
LGBM_specificity_v2 = [0.7000, 0.7500, 0.8036, 0.8302, 0.7250, 0.7857, 0.6885, 0.7209, 0.7445]
LGBM_sensitivity_v2 = [0.7143, 0.8866, 0.8646, 0.6296, 0.9474, 0.9125, 0.8021, 0.8298, 0.8569]

# %%
#Extreme Gradient boosting models

XGBM = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]
XGBM_accuracy = [0.7329, 0.8431, 0.8224, 0.7875, 0.8889, 0.9167, 0.7898, 0.8000]
XGBM_specificity = [0.6429, 0.7857, 0.7679, 0.8491, 0.7750, 0.8571, 0.6721, 0.7442]
XGBM_sensitivity = [0.8022, 0.8763, 0.8542, 0.6667, 0.9368, 0.9375, 0.8646, 0.8511] 

XGBM_v2 = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All"]
XGBM_accuracy_v2 = [0.7329, 0.8431, 0.8224, 0.7875, 0.8889, 0.9167, 0.7898, 0.8000, 0.8320]
XGBM_specificity_v2 = [0.6429, 0.7857, 0.7679, 0.8491, 0.7750, 0.8571, 0.6721, 0.7442, 0.7666]
XGBM_sensitivity_v2 = [0.8022, 0.8763, 0.8542, 0.6667, 0.9368, 0.9375, 0.8646, 0.8511, 0.8744]

# %%
#col = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]
#accuracy = []
#specificty = []
#sensitivity = []

# %%
model = ["GBM", "LGBM", "XGBM"]
accuracy = [0.8301, 0.8127, 0.8320]
specificity = [0.7469, 0.7445, 0.7666]
sensitivity = [0.8839, 0.8569, 0.8744]
AUC = [0.9021 +- 0.0111, 0.8936 +-0.0256, 0.8984 +- 0.0187]

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(20, 10)) 

ax1.bar(model, accuracy, tick_label=model)
ax1.set_title("Accuracy for Gradient Boosting Models")
ax1.set_xlabel("GB Model")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([.7, .89])

ax2.bar(model, sensitivity, tick_label=model)
ax2.set_title("Sensitivity for Gradient Boosting Models")
ax2.set_xlabel("GB Model")
ax2.set_ylabel("Sensitivity")
ax2.set_ylim([.7, .89])

ax3.bar(model, specificity, tick_label=model)
ax3.set_title("Specificity for Gradient Boosting Models")
ax3.set_xlabel("GB Model")
ax3.set_ylabel("Specificity")
ax3.set_ylim([.70, .85])
# Out:
# (0.7, 0.85)

# %%
sites = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]

x = np.arange(len(sites))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GBM_accuracy, width, label='GBM')
rects2 = ax.bar(x, LGBM_accuracy, width, label='LGBM')
rects3 = ax.bar(x+width, XGBM_accuracy, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
x = np.arange(len(LGBM))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GBM_sensitivity, width, label='GBM')
rects2 = ax.bar(x, LGBM_sensitivity, width, label='LGBM')
rects3 = ax.bar(x+width, XGBM_sensitivity, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Sensitivity')
ax.set_title('Sensitivity for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
x = np.arange(len(sites))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GBM_specificity, width, label='GBM')
rects2 = ax.bar(x, LGBM_specificity, width, label='LGBM')
rects3 = ax.bar(x+width, XGBM_specificity, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Specificity')
ax.set_title('Specificity for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
#Sensitivity, specificity, accuracy
GB = [0.8839, 0.7469, 0.8301]
LGB = [0.8569, 0.7445, 0.8127]
XGB = [0.8744, 0.7666, 0.8320]

# %%
values = ["Sensitvity", "Specificity", "Accuracy"]

x = np.arange(len(values))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GB, width, label='GBM')
rects2 = ax.bar(x, LGB, width, label='LGBM')
rects3 = ax.bar(x+width, XGB, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('')
ax.set_title('Specificity for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(values, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.6, .90])

plt.show()

# %%
values = ["Sensitvity", "Specificity", "Accuracy"]

x = np.arange(len(values))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GB, width, label='GBM')
rects2 = ax.bar(x, LGB, width, label='LGBM')
rects3 = ax.bar(x+width, XGB, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('')
ax.set_title('Specificity for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(values, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)
ax.bar_label(rects3, padding=3)

fig.tight_layout()
ax.set_ylim([.6, .90])

plt.show()

# %%
sites = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All"]

x = np.arange(len(sites))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GBM_accuracy_v2, width, label='GBM')
rects2 = ax.bar(x, LGBM_accuracy_v2, width, label='LGBM')
rects3 = ax.bar(x+width, XGBM_accuracy_v2, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
x = np.arange(len(sites))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GBM_sensitivity_v2, width, label='GBM')
rects2 = ax.bar(x, LGBM_sensitivity_v2, width, label='LGBM')
rects3 = ax.bar(x+width, XGBM_sensitivity_v2, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Sensitivity')
ax.set_title('Sensitivity for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
x = np.arange(len(sites))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, GBM_specificity_v2, width, label='GBM')
rects2 = ax.bar(x, LGBM_specificity_v2, width, label='LGBM')
rects3 = ax.bar(x+width, XGBM_specificity_v2, width, label='XGBM')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Specificity')
ax.set_title('Specificity for different wetland sites')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
#CastleBay_GB_AUC = [.6249, .7778, .9307, "GB"]
#CastleBay_LGB_AUC = [.6701, .7541, .8381, "LGB"]
#CastleBay_XGB_AUC = [.673, .7752, .8774, "XGB"]
#MasonHT_GB_AUC = [.8245, .8694, .9143, "GB"]
#MasonHT_LGB_AUC = [.8719, .9162, .9605, "LGB"]
#MasonHT_XGB_AUC = [.8716, .9153, .959, "XGB"]
#MasonLT_GB_AUC = [.7724, .8475, .9226, "GB"]
#MasonLT_LGB_AUC = [.8368, .8981, .9594, "LGB"]
#MasonLT_XGB_AUC = [.8599, .9069, .9539, "XGB"]
#Maysville_GB_AUC = [.6688, .7613, .8538, "GB"]
#Maysville_LGB_AUC = [.772, .8271, .8822, "LGB"]
#Maysville_XGB_AUC = [.7971, .8967, .9963, "XGB"]
#RiverRoad_GB_AUC = [.8247, .8740, .9233, "GB"]
#RiverRoad_LGB_AUC = [.7723, .8883, 1.0043, "LGB"]
#Has a standard deviation with upperbound greater than 1.0
#RiverRoad_XGB_AUC = [.7808, .9015, 1.0222, "XGB"]
#StJames_GB_AUC = [.7541, .8886, 1.0231, "GB"]
#StJames_LGB_AUC = [.9114, .9538, .9962, "LGB"]
#StJames_XGB_AUC = [.8966, .9545, 1.0124, "XGB"]
#SurfCity_GB_AUC = [.8056, .8777, .9498, "GB"]
#SurfCity_LGB_AUC = [.743, .8223, .9016, "LGB"]
#SurfCity_XGB_AUC = [.7688, .8354, .902, "XGB"]
#Topsail_GB_AUC = [.6834, .8276, .9718, "GB"]
#Topsail_LGB_AUC = [.7502, .8680, .9858, "LGB"]
#Topsail_XGB_AUC = [.8087, .8934, .9781, "XGB"]
#All__GB_AUC = [.891, .9021, .9132]
#All_LGB_AUC = [.868, .9192, .8797]
#All_XGB_AUC = [.8797, .8984, .9171]

df = pd.DataFrame({"Sites": ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All", "All", "All", "All", "All", "All", "All", "All", "All"],
                   "model": ["GB", "LGB", "XGB", "GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB", "GB", "LGB", "XGB", "GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB", "GB", "LGB", "XGB", "GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB", "GB", "GB", "GB", "LGB", "LGB", "LGB", "XGB", "XGB", "XGB"], 
                   "AUC": [.6249, .6701, .673, .8245, .8719, .8716, .7724, .8368, .8599, .6688, .772, .7971, .8247, .7723, .7808, .7541, .9114, .8966, .8056, .743, .7688, .6834, .7502, .8087, .7778, .7541, .7752, .8694, .9162, .9153, .8475, .8981, .9069, .7613, .8271, .8967, .8740, .8883, .9015, .8886, .9538, .9545, .8777, .8223, .8354, .8276, .8680, .8934, .9307, .8381, .8774, .9143, .9605, .959, .9226, .9594, .9539, .8538, .8822, .9963, .9233, 1.0043, 1.0222, 1.0231, .9962, 1.0124, .9498, .9016, .902, .9718, .9858, .9781, .891, .9021, .9132, .868, .9192, .8797, .8797, .8984, .9171] })
df2 = pd.DataFrame({"Sites": ["All", "All", "All", "All", "All", "All", "All", "All", "All"],
                   "model": ["GB", "GB", "GB", "LGB", "LGB", "LGB", "XGB", "XGB", "XGB"], 
                   "AUC": [.891, .9021, .9132, .868, .9192, .8797, .8797, .8984, .9171] })
df3 = pd.DataFrame({"Sites": ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"],
                   "model": ["GB", "LGB", "XGB", "GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB", "GB", "LGB", "XGB", "GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB", "GB", "LGB", "XGB", "GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB","GB", "LGB", "XGB"], 
                   "AUC": [.6249, .6701, .673, .8245, .8719, .8716, .7724, .8368, .8599, .6688, .772, .7971, .8247, .7723, .7808, .7541, .9114, .8966, .8056, .743, .7688, .6834, .7502, .8087, .7778, .7541, .7752, .8694, .9162, .9153, .8475, .8981, .9069, .7613, .8271, .8967, .8740, .8883, .9015, .8886, .9538, .9545, .8777, .8223, .8354, .8276, .8680, .8934, .9307, .8381, .8774, .9143, .9605, .959, .9226, .9594, .9539, .8538, .8822, .9963, .9233, 1.0043, 1.0222, 1.0231, .9962, 1.0124, .9498, .9016, .902, .9718, .9858, .9781] })

#cols = ["CastleBay_GB_AUC", "MasonHT_GB_AUC", "MasonLT_GB_AUC", "Maysville_GB_AUC", "RiverRoad_GB_AUC", "StJames_GB_AUC", "SurfCity_GB_AUC", "Topsail_GB_AUC", "CastleBay_LGB_AUC", "MasonHT_LGB_AUC", "MasonLT_LGB_AUC", "Maysville_LGB_AUC", "RiverRoad_LGB_AUC", "StJames_LGB_AUC", "SurfCity_LGB_AUC", "Topsail_LGB_AUC", "CastleBay_XGB_AUC", "MasonHT_XGB_AUC", "MasonLT_XGB_AUC", "Maysville_XGB_AUC", "RiverRoad_XGB_AUC", "StJames_XGB_AUC", "SurfCity_XGB_AUC", "Topsail_XGB_AUC"]

#df = pd.DataFrame(list(zip(CastleBay_GB_AUC, MasonHT_GB_AUC, MasonLT_GB_AUC, Maysville_GB_AUC, RiverRoad_GB_AUC, StJames_GB_AUC, SurfCity_GB_AUC, Topsail_GB_AUC, CastleBay_LGB_AUC, MasonHT_LGB_AUC, MasonLT_LGB_AUC, Maysville_LGB_AUC, RiverRoad_LGB_AUC, StJames_LGB_AUC, SurfCity_LGB_AUC, Topsail_LGB_AUC, CastleBay_XGB_AUC, MasonHT_XGB_AUC, MasonLT_XGB_AUC, Maysville_XGB_AUC, RiverRoad_XGB_AUC, StJames_XGB_AUC, SurfCity_XGB_AUC, Topsail_XGB_AUC)),columns = cols)
sns.set(font_scale=0.6)
ax = sns.pointplot(x="Sites", y="AUC", hue="model", data=df, dodge= 0.3, join = False)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(16,6))
sns.set(font_scale=0.6)
sns.pointplot(x="Sites", y="AUC", hue="model", dodge = 0.3, data=df3, kind = "point", ax = ax1, join = False)
sns.pointplot(x="Sites", y="AUC", hue = "model", dodge = 0.3, data = df2, kind = "point", ax = ax2, join = False)
#g = sns.FacetGrid(df, col="time",  row="sex")
#g.map_dataframe(sns.histplot, x="total_bill")
# Sites AUC GB model
# 8
# Out:
# <AxesSubplot:xlabel='Sites', ylabel='AUC'>

# %%
#GBM_v2 = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All"]
#GBM_accuracy_v2 = [0.7329, 0.8366, 0.7961, 0.7250, 0.8370, 0.8796, 0.8153, 0.7889, 0.8301]
#GBM_specificity_v2 = [0.7000, 0.7679, 0.7500, 0.8113, 0.7500, 0.7500, 0.7705, 0.7209, 0.7469]
#GBM_sensitivity_v2 = [0.7582, 0.8763, 0.8229, 0.5556, 0.8737, 0.9250, 0.8438, 0.8511, 0.8839]
#LGBM_accuracy_v2 = [0.7081, 0.8366, 0.8421, 0.7625, 0.8815, 0.8796, 0.7580, 0.7778, 0.8127]
#LGBM_specificity_v2 = [0.7000, 0.7500, 0.8036, 0.8302, 0.7250, 0.7857, 0.6885, 0.7209, 0.7445]
#LGBM_sensitivity_v2 = [0.7143, 0.8866, 0.8646, 0.6296, 0.9474, 0.9125, 0.8021, 0.8298, 0.8569]
#XGBM_accuracy_v2 = [0.7329, 0.8431, 0.8224, 0.7875, 0.8889, 0.9167, 0.7898, 0.8000, 0.8320]
#XGBM_specificity_v2 = [0.6429, 0.7857, 0.7679, 0.8491, 0.7750, 0.8571, 0.6721, 0.7442, 0.7666]
#XGBM_sensitivity_v2 = [0.8022, 0.8763, 0.8542, 0.6667, 0.9368, 0.9375, 0.8646, 0.8511, 0.8744]
df3 = pd.DataFrame({"Sites": ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All", "CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail", "All"],
                   "Accuracy": [0.7329, 0.8366, 0.7961, 0.7250, 0.8370, 0.8796, 0.8153, 0.7889, 0.8301, 0.7081, 0.8366, 0.8421, 0.7625, 0.8815, 0.8796, 0.7580, 0.7778, 0.8127, 0.7329, 0.8431, 0.8224, 0.7875, 0.8889, 0.9167, 0.7898, 0.8000, 0.8320],
                   "Specificity": [0.7000, 0.7679, 0.7500, 0.8113, 0.7500, 0.7500, 0.7705, 0.7209, 0.7469, 0.7000, 0.7500, 0.8036, 0.8302, 0.7250, 0.7857, 0.6885, 0.7209, 0.7445, 0.6429, 0.7857, 0.7679, 0.8491, 0.7750, 0.8571, 0.6721, 0.7442, 0.7666],
                   "Sensitivity": [0.7582, 0.8763, 0.8229, 0.5556, 0.8737, 0.9250, 0.8438, 0.8511, 0.8839, 0.7143, 0.8866, 0.8646, 0.6296, 0.9474, 0.9125, 0.8021, 0.8298, 0.8569, 0.8022, 0.8763, 0.8542, 0.6667, 0.9368, 0.9375, 0.8646, 0.8511, 0.8744],
                   "Model": ["GB", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "GB", "LGB", "LGB", "LGB", "LGB", "LGB", "LGB", "LGB", "LGB", "LGB", "XGB", "XGB", "XGB", "XGB", "XGB", "XGB", "XGB", "XGB", "XGB"]})

# %%
fig, ax = plt.subplots(1, 3, figsize=(16,4), constrained_layout=True)
fig.suptitle("Sites vs Performance Data")
font_dict = {'fontsize': 4, 'fontweight': 'normal', 'verticalalignment':'top'}

ax1=sns.barplot(ax=ax[0], x=df3.Sites,y=df3.Accuracy,hue=df3.Model, errwidth = False)
ax2=sns.barplot(ax=ax[1], x=df3.Sites,y=df3.Sensitivity,hue=df3.Model,errwidth = False)
ax3=sns.barplot(ax=ax[2], x=df3.Sites,y=df3.Specificity,hue=df3.Model,errwidth = False)
ax1.set_ylim(0.5, 1)
ax2.set_ylim(0.5, 1)
ax3.set_ylim(0.5, 1)
height = 0.5

# %%
#sites = ["CastleBay", "MasonHT", "MasonLT", "Maysville", "RiverRoad", "StJames", "SurfCity", "Topsail"]

#x = np.arange(len(sites))  # the label locations
#width = 0.25  # the width of the bars

#fig, ax = plt.subplots()
#rects1 = ax.bar(x-width, GBM_accuracy, width, label='GBM')
#rects2 = ax.bar(x, LGBM_accuracy, width, label='LGBM')
#rects3 = ax.bar(x+width, XGBM_accuracy, width, label='XGBM')
# Add some text for labels, title and custom x-axis tick labels, etc.
#font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
#ax.set_ylabel('Accuracy')
#ax.set_title('Accuracy for different wetland sites')
#ax.set_xticks(x + width / 3)
#ax.set_xticklabels(sites, fontdict = font_dict)
#ax.set_xlabel('Sites', labelpad=15)
#ax.legend()

#fig.tight_layout()
#ax.set_ylim([.5, 1])

#plt.show()

#plt.style.use('_mpl-gallery')

# %%
#XGB comparison since it was the highest performing one

x = np.arange(len(sites))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x-width, XGBM_sensitivity_v2, width, label='Sensitivity')
rects2 = ax.bar(x, XGBM_specificity_v2, width, label='Specificity')
rects3 = ax.bar(x+width, XGBM_accuracy_v2, width, label='Accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
font_dict = {'fontsize': 8, 'fontweight': 'normal', 'verticalalignment':'top'}
ax.set_ylabel('Performance proportion')
ax.set_title('Performance data for XGB model')
ax.set_xticks(x + width / 3)
ax.set_xticklabels(sites, fontdict = font_dict)
ax.set_xlabel('Sites', labelpad=15)
ax.legend()

fig.tight_layout()
ax.set_ylim([.5, 1])

plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(16,4), constrained_layout=True)
fig.suptitle("Sites vs Performance Data")
font_dict = {'fontsize': 4, 'fontweight': 'normal', 'verticalalignment':'top'}

ax1=sns.barplot(ax=ax[0], x=df3.Sites,y=df3.Accuracy,hue=df3.Model, errwidth = False)
ax2=sns.barplot(ax=ax[1], x=df3.Sites,y=df3.Sensitivity,hue=df3.Model,errwidth = False)
ax3=sns.barplot(ax=ax[2], x=df3.Sites,y=df3.Specificity,hue=df3.Model,errwidth = False)
ax1.set_ylim(0.5, 1)
ax2.set_ylim(0.5, 1)
ax3.set_ylim(0.5, 1)
height = 0.5
