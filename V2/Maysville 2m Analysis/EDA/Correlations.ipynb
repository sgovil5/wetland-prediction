# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
import dataframe_image as dfi
# %matplotlib inline
plt.rcParams['figure.dpi'] = 70 #display 70 dpi in Jupyter Notebook, may consider100 dpi 
plt.rcParams['savefig.dpi'] = 70 #define 300 dpi for saving figures
sns.set_style('whitegrid')
sns.set(rc={"figure.dpi":70, 'savefig.dpi':70}) #defining dpi setting
sns.set_context('notebook')
sns.set_style("ticks")
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

# %%
dfes = pd.read_csv('../Maysville_multi_quan.csv')
dfes['FID_RiverRd_AOI'] = np.where(dfes['NWI']=='wetland', 1, 0)
#dfes['NWI'] = np.where(dfes['NWI']=='wetland', 'wetland', 'nonwetland')
dfes['NWI'].value_counts()
# Out:
# nonwetland    10189
# wetland        7159
# Name: NWI, dtype: int64

# %%
#Identifier is MIN, MAX, MEAN, RANGE etc.
def create_heatmap(identifier, ax, title):
    cols = []
    for (columnName, columnData) in dfes.iteritems():
        if identifier in columnName:
            cols.append(columnName)
    dfes_temp = pd.DataFrame(dfes, columns=cols)
    corr = dfes_temp.corr()
    ax.set_title(title)
    sns.heatmap(corr, cmap="Blues", ax=ax, square=True)

# %%
identifier_list = ["MIN", "MAX", "RANGE", "MEAN", "STD", "MEDIAN"]
fig,axn = plt.subplots(3, 2, figsize=(20,30))
i = 0
for ax in axn.flat:
    create_heatmap(identifier_list[i], ax, f"Correlation between {identifier_list[i]} of all Variables")
    ax.tick_params(axis='x', labelrotation=75)
    i+=1
fig.savefig('../Images/corr_heatmap.jpg')

# %%
corr = dfes.corr()
df_corr = pd.DataFrame(corr['FID_RiverRd_AOI'])
df_corr = df_corr[:-1].sort_values(by=["FID_RiverRd_AOI"])
pd.set_option('display.max_rows', None)
df_corr
# Out:
#              FID_RiverRd_AOI
# DEMs_MAX           -0.721513
# DEM_MAX            -0.720169
# DEMs_MEAN          -0.716623
# DEMs_MEDIAN        -0.716521
# DEMh_MAX           -0.716384
# DEM_MEDIAN         -0.715945
# DEM_MEAN           -0.715901
# DEMs_SUM           -0.713033
# DEM_SUM            -0.712325
# DEMs_MIN           -0.711467
# DEM_MIN            -0.711089
# DEMh_MEAN          -0.706892
# DEMh_MEDIAN        -0.706576
# DEMh_SUM           -0.703149
# DEMh_MIN           -0.698512
# DSM_MIN            -0.658590
# DSM_MEAN           -0.381019
# DSM_SUM            -0.380642
# DSM_MEDIAN         -0.363326
# DEMh_RANGE         -0.333215
# DEMh_STD           -0.326051
# asp_MIN            -0.303805
# DEMs_RANGE         -0.285936
# DEMs_STD           -0.283559
# FlAc_MEAN          -0.227590
# FlAc_SUM           -0.227569
# curv_MIN           -0.205955
# FlAc_STD           -0.204300
# slo_MIN            -0.199202
# FlAc_MAX           -0.195667
# plC_MIN            -0.194771
# FlAc_RANGE         -0.193787
# NDRE_MIN           -0.185729
# proC_MIN           -0.177949
# NDVI_RANGE         -0.157905
# DSM_MAX            -0.142754
# NDVI_STD           -0.133779
# curv_MEDIAN        -0.108464
# FlAc_MEDIAN        -0.095451
# FlD_MIN            -0.092037
# NDVI_MAX           -0.091863
# NDWI_RANGE         -0.077497
# asp_MEDIAN         -0.069322
# asp_MEAN           -0.066700
# NDWI_STD           -0.066680
# asp_SUM            -0.066352
# FlAc_MIN           -0.061077
# DEM_STD            -0.053177
# NDVI_MEDIAN        -0.041339
# NDVI_SUM           -0.039817
# NDVI_MEAN          -0.039807
# DEM_RANGE          -0.022726
# slo_MEDIAN         -0.018205
# curv_SUM           -0.004879
# curv_MEAN          -0.004603
# slo_SUM             0.014754
# slo_MEAN            0.015069
# FlD_MEDIAN          0.019486
# NDVI_MIN            0.019996
# plC_MEDIAN          0.077627
# DSM_STD             0.087944
# NDWI_MAX            0.093927
# NDRE_MEDIAN         0.096197
# NDRE_SUM            0.099125
# NDRE_MEAN           0.099147
# DSM_RANGE           0.116017
# NDWI_SUM            0.117450
# NDWI_MEAN           0.117501
# NDWI_MEDIAN         0.117568
# NDWI_MIN            0.140945
# proC_MEAN           0.159059
# proC_SUM            0.159288
# slo_MAX             0.165688
# curv_MAX            0.170311
# proC_MEDIAN         0.170329
# plC_SUM             0.170366
# plC_MEAN            0.170702
# plC_MAX             0.178561
# FlD_SUM             0.180835
# FlD_MEAN            0.180891
# curv_RANGE          0.194252
# plC_RANGE           0.197459
# proC_RANGE          0.198704
# proC_MAX            0.207827
# plC_STD             0.218517
# curv_STD            0.220963
# proC_STD            0.223119
# slo_STD             0.224968
# slo_RANGE           0.225798
# NDRE_MAX            0.245039
# NDRE_STD            0.275691
# FlD_STD             0.284935
# NDRE_RANGE          0.299951
# asp_MAX             0.320619
# FlD_RANGE           0.324240
# FlD_MAX             0.328749
# asp_RANGE           0.375845
# asp_STD             0.388461

# %%
df_corr.abs().sort_values(by=["FID_RiverRd_AOI"])[::-1]
# Out:
#              FID_RiverRd_AOI
# DEMs_MAX            0.721513
# DEM_MAX             0.720169
# DEMs_MEAN           0.716623
# DEMs_MEDIAN         0.716521
# DEMh_MAX            0.716384
# DEM_MEDIAN          0.715945
# DEM_MEAN            0.715901
# DEMs_SUM            0.713033
# DEM_SUM             0.712325
# DEMs_MIN            0.711467
# DEM_MIN             0.711089
# DEMh_MEAN           0.706892
# DEMh_MEDIAN         0.706576
# DEMh_SUM            0.703149
# DEMh_MIN            0.698512
# DSM_MIN             0.658590
# asp_STD             0.388461
# DSM_MEAN            0.381019
# DSM_SUM             0.380642
# asp_RANGE           0.375845
# DSM_MEDIAN          0.363326
# DEMh_RANGE          0.333215
# FlD_MAX             0.328749
# DEMh_STD            0.326051
# FlD_RANGE           0.324240
# asp_MAX             0.320619
# asp_MIN             0.303805
# NDRE_RANGE          0.299951
# DEMs_RANGE          0.285936
# FlD_STD             0.284935
# DEMs_STD            0.283559
# NDRE_STD            0.275691
# NDRE_MAX            0.245039
# FlAc_MEAN           0.227590
# FlAc_SUM            0.227569
# slo_RANGE           0.225798
# slo_STD             0.224968
# proC_STD            0.223119
# curv_STD            0.220963
# plC_STD             0.218517
# proC_MAX            0.207827
# curv_MIN            0.205955
# FlAc_STD            0.204300
# slo_MIN             0.199202
# proC_RANGE          0.198704
# plC_RANGE           0.197459
# FlAc_MAX            0.195667
# plC_MIN             0.194771
# curv_RANGE          0.194252
# FlAc_RANGE          0.193787
# NDRE_MIN            0.185729
# FlD_MEAN            0.180891
# FlD_SUM             0.180835
# plC_MAX             0.178561
# proC_MIN            0.177949
# plC_MEAN            0.170702
# plC_SUM             0.170366
# proC_MEDIAN         0.170329
# curv_MAX            0.170311
# slo_MAX             0.165688
# proC_SUM            0.159288
# proC_MEAN           0.159059
# NDVI_RANGE          0.157905
# DSM_MAX             0.142754
# NDWI_MIN            0.140945
# NDVI_STD            0.133779
# NDWI_MEDIAN         0.117568
# NDWI_MEAN           0.117501
# NDWI_SUM            0.117450
# DSM_RANGE           0.116017
# curv_MEDIAN         0.108464
# NDRE_MEAN           0.099147
# NDRE_SUM            0.099125
# NDRE_MEDIAN         0.096197
# FlAc_MEDIAN         0.095451
# NDWI_MAX            0.093927
# FlD_MIN             0.092037
# NDVI_MAX            0.091863
# DSM_STD             0.087944
# plC_MEDIAN          0.077627
# NDWI_RANGE          0.077497
# asp_MEDIAN          0.069322
# asp_MEAN            0.066700
# NDWI_STD            0.066680
# asp_SUM             0.066352
# FlAc_MIN            0.061077
# DEM_STD             0.053177
# NDVI_MEDIAN         0.041339
# NDVI_SUM            0.039817
# NDVI_MEAN           0.039807
# DEM_RANGE           0.022726
# NDVI_MIN            0.019996
# FlD_MEDIAN          0.019486
# slo_MEDIAN          0.018205
# slo_MEAN            0.015069
# slo_SUM             0.014754
# curv_SUM            0.004879
# curv_MEAN           0.004603
